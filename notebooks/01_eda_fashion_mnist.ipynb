# %% [markdown]
# # 01_eda_fashion_mnist
#
# EDA du dataset retenu (Fashion-MNIST, voir `HISTORY.md`). Exécute la même analyse que `scripts/eda_fashion_mnist.py` et affiche la grille d'exemples inline.
#
# Prérequis : dataset déjà téléchargé dans `data/raw/` (`scripts/download_and_eda.py` ou `scripts/resumable_download.py`).

# %%
import sys
from pathlib import Path

# Le cwd de Jupyter est `notebooks/` : ajouter la racine du repo pour pouvoir importer `scripts.*`.
root = Path().resolve().parent
if str(root) not in sys.path:
    sys.path.insert(0, str(root))

import os
os.chdir(root)  # les chemins du script (data/raw, reports/) sont relatifs à la racine du repo

from scripts.eda_fashion_mnist import run

run()
# Out:
# Rapport écrit dans reports\eda_fashion_mnist.md
# Grille d'exemples écrite dans reports\samples\fashion_mnist_grid.png

# %%
from IPython.display import Image, display

display(Image(filename=str(root / 'reports' / 'samples' / 'fashion_mnist_grid.png')))
